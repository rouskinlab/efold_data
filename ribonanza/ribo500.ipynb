# %% [markdown]
# ## Ribo500
#
# Ribo500 is a subset of Ribonanza. It contains references with # of reads > 500 and S/N > 1.

# %%
import json
import pandas as pd
import rouskinhf as rhf
import numpy as np
import json
import tqdm
tqdm.tqdm.pandas()

# %%
# Load data
data = json.load(open('data/clean_ribonanza.json'))
df_all = pd.read_csv('~/data/ribonanza/train_data.csv')

# filter
df = df_all[(df_all['reads'] > 500) & (df_all['signal_to_noise'] > 1)].copy()
df = df.rename(columns={'sequence_id': 'reference'}).sort_values('reads', ascending=False).drop_duplicates(['reference','experiment_type'], keep='first')

# %%
# get the signals
reactivity_cols = [c for c in df.columns if c.startswith('reactivity_0')]
signals = df[reactivity_cols].values.tolist()
df = df[['reference', 'sequence', 'experiment_type']].copy()
df['signal'] = signals
df['signal'] = df.progress_apply(lambda row: [x if s in 'AC' and not np.isnan(x) else -1000. for x, s in zip(row['signal'], row['sequence'])], axis=1)
df
# Out:
# 100%|██████████| 357388/357388 [00:16<00:00, 21420.05it/s]
#             reference                                           sequence  \
# 1638157  3e6c574877dd  GGGAACGACUCGAGUAGAGUCGAAAAAUGACGGGUCCUCUGAGCUU...
# 1625526  ebe90364da34  GGGAACGACUCGAGUAGAGUCGAAAAACUUUUCGACUCUGAUACCA...
# 1627292  3e6c574877dd  GGGAACGACUCGAGUAGAGUCGAAAAAUGACGGGUCCUCUGAGCUU...
# 1622797  ebe90364da34  GGGAACGACUCGAGUAGAGUCGAAAAACUUUUCGACUCUGAUACCA...
# 1636948  04b293ab47f6  GGGAACGACUCGAGUAGAGUCGAAAAGAGAGCGUAGCACACACACA...
# ...               ...                                                ...
# 947668   6395be7c964b  GGGAACGACUCGAGUAGAGUCGAAAACGGCGAGCGUCCCGGACCGG...
# 612108   ea1da33f1fd1  GGGAACGACUCGAGUAGAGUCGAAAAGCUAAUAUGCUAGAUGUCUC...
# 1587570  6dce49c4a068  GGGAACGACUCGAGUAGAGUCGAAAACAGCGGACCAGCAAAGCAUG...
# 1475958  bbea23ef018b  GGGAACGACUCGAGUAGAGUCGAAAAUGGCCUGCGUACUGGCGCUC...
# 937411   22507659e7a1  GGGAACGACUCGAGUAGAGUCGAAAAAGCGAAAGACGAGUGAGAAA...
#
#         experiment_type                                             signal
# 1638157         DMS_MaP  [-1000.0, -1000.0, -1000.0, -1000.0, -1000.0, ...
# 1625526         DMS_MaP  [-1000.0, -1000.0, -1000.0, -1000.0, -1000.0, ...
# 1627292         2A3_MaP  [-1000.0, -1000.0, -1000.0, -1000.0, -1000.0, ...
# 1622797         2A3_MaP  [-1000.0, -1000.0, -1000.0, -1000.0, -1000.0, ...
# 1636948         DMS_MaP  [-1000.0, -1000.0, -1000.0, -1000.0, -1000.0, ...
# ...                 ...                                                ...
# 947668          DMS_MaP  [-1000.0, -1000.0, -1000.0, -1000.0, -1000.0, ...
# 612108          2A3_MaP  [-1000.0, -1000.0, -1000.0, -1000.0, -1000.0, ...
# 1587570         DMS_MaP  [-1000.0, -1000.0, -1000.0, -1000.0, -1000.0, ...
# 1475958         2A3_MaP  [-1000.0, -1000.0, -1000.0, -1000.0, -1000.0, ...
# 937411          DMS_MaP  [-1000.0, -1000.0, -1000.0, -1000.0, -1000.0, ...
#
# [357388 rows x 4 columns]

# %%
df_out = pd.merge(
    df[df['experiment_type'] == '2A3_MaP'].rename(columns={'signal': 'shape'})[['sequence', 'shape',  'reference']],
    df[df['experiment_type'] == 'DMS_MaP'].rename(columns={'signal': 'dms'})[['sequence', 'dms', 'reference']],
    on=['reference', 'sequence'], how='outer'
).set_index('reference')

df_out
# Out:
#                                                           shape  \
# reference
# 3e6c574877dd  [-1000.0, -1000.0, -1000.0, -1000.0, -1000.0, ...
# ebe90364da34  [-1000.0, -1000.0, -1000.0, -1000.0, -1000.0, ...
# 04b293ab47f6  [-1000.0, -1000.0, -1000.0, -1000.0, -1000.0, ...
# 438571322af3  [-1000.0, -1000.0, -1000.0, -1000.0, -1000.0, ...
# 6ea263220d58  [-1000.0, -1000.0, -1000.0, -1000.0, -1000.0, ...
# ...                                                         ...
# e7e971271ffb                                                NaN
# 74b7990f9332                                                NaN
# d5ef12473c37                                                NaN
# 9873f40d0f30                                                NaN
# 6395be7c964b                                                NaN
#
#                                                        sequence  \
# reference
# 3e6c574877dd  GGGAACGACUCGAGUAGAGUCGAAAAAUGACGGGUCCUCUGAGCUU...
# ebe90364da34  GGGAACGACUCGAGUAGAGUCGAAAAACUUUUCGACUCUGAUACCA...
# 04b293ab47f6  GGGAACGACUCGAGUAGAGUCGAAAAGAGAGCGUAGCACACACACA...
# 438571322af3  GGGAACGACUCGAGUAGAGUCGAAAAUAGUGCGUGGACGCACCCAC...
# 6ea263220d58  GGGAACGACUCGAGUAGAGUCGAAAAGAGCGUCGCACACACGCAGA...
# ...                                                         ...
# e7e971271ffb  GGGAACGACUCGAGUAGAGUCGAAAAUUCUUUAGUAAUUACCUAAA...
# 74b7990f9332  GGGAACGACUCGAGUAGAGUCGAAAAGAUAUGGACUCAGGGAGUGA...
# d5ef12473c37  GGGAACGACUCGAGUAGAGUCGAAAAGGUGAAUGUGUUCCUGAGCC...
# 9873f40d0f30  GGGAACGACUCGAGUAGAGUCGAAAAGCCGUUUUCAAUGUGUAGAU...
# 6395be7c964b  GGGAACGACUCGAGUAGAGUCGAAAACGGCGAGCGUCCCGGACCGG...
#
#                                                             dms
# reference
# 3e6c574877dd  [-1000.0, -1000.0, -1000.0, -1000.0, -1000.0, ...
# ebe90364da34  [-1000.0, -1000.0, -1000.0, -1000.0, -1000.0, ...
# 04b293ab47f6  [-1000.0, -1000.0, -1000.0, -1000.0, -1000.0, ...
# 438571322af3  [-1000.0, -1000.0, -1000.0, -1000.0, -1000.0, ...
# 6ea263220d58  [-1000.0, -1000.0, -1000.0, -1000.0, -1000.0, ...
# ...                                                         ...
# e7e971271ffb  [-1000.0, -1000.0, -1000.0, -1000.0, -1000.0, ...
# 74b7990f9332  [-1000.0, -1000.0, -1000.0, -1000.0, -1000.0, ...
# d5ef12473c37  [-1000.0, -1000.0, -1000.0, -1000.0, -1000.0, ...
# 9873f40d0f30  [-1000.0, -1000.0, -1000.0, -1000.0, -1000.0, ...
# 6395be7c964b  [-1000.0, -1000.0, -1000.0, -1000.0, -1000.0, ...
#
# [209121 rows x 3 columns]

# %%
bpp = pd.read_json('data/bpp.json', orient='index')

# %%
df_out = pd.merge(df_out, bpp, left_index=True, right_index=True, how='left')

# %%
rhf.dump_json(df_out.to_dict(orient='index'), 'data/ribo500.json')

# %%
from rouskinhf import convert

data = convert('json', 'data/ribo500.json')
# Out:
# Parsing json file: 100%|██████████| 209121/209121 [00:14<00:00, 14093.01it/s]
# Over a total of 209121 datapoints, there are:
# ### OUTPUT
# - ALL: 124811 valid datapoints
# - INCLUDED: 0 duplicate sequences with different structure / dms / shape
# ### MODIFIED
# - 0 multiple sequences with the same reference (renamed reference)
# ### FILTERED OUT
# - 0 invalid datapoints (ex: sequence with non-regular characters)
# - 0 datapoints with bad structures
# - 0 duplicate sequences with the same structure / dms / shape
# - 84310 datapoints removed because of low AUROC (<0.8)

# %%
from rouskinhf import upload_dataset
import envbash
envbash.load.load_envbash('../.env')

upload_dataset(
    datapath='./data/ribo500/data.json',
    exist_ok=True,
)
# Out:
# data.json:   0%|          | 0.00/408M [00:00<?, ?B/s]
